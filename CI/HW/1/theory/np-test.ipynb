# %%
import numpy as np

# %%
a1 = np.array([[1,2],[3,4],[5,6]])
a1.shape
# Out:
# (3, 2)

# %%
a2 = np.array([[1,2,3],[4,5,6]])
a2.shape
# Out:
# (2, 3)

# %%
r1 = a2 @ a1
r1
# Out:
# array([[22, 28],
#        [49, 64]])

# %%
r2 = a1 @ a2
r2
# Out:
# array([[ 9, 12, 15],
#        [19, 26, 33],
#        [29, 40, 51]])

# %%
r3 = 5 * a1
r3
# Out:
# array([[ 5, 10],
#        [15, 20],
#        [25, 30]])

# %%
r4 = a2 * a2
r4
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])
